# %% [markdown]
# # Assignment: Data Tool Kit.

# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python ?

# %% [markdown]
# -> NumPy (Numerical Python) is a Python library used for working with large arrays and mathematical operations.
# It is widely used because it is fast, memory-efficient, and supports vectorized operations.

# %% [markdown]
# 2.  How does broadcasting work in NumPy ?

# %% [markdown]
# -> Broadcasting allows NumPy to perform operations on arrays of different shapes by automatically expanding the smaller array.

# %%
import numpy as np
a = np.array([1, 2, 3])
print(a + 5)
# Out:
# [6 7 8]

# %% [markdown]
# 3. What is a Pandas DataFrame ?

# %% [markdown]
# -> A Pandas DataFrame is a 2-dimensional table with rows and columns, similar to an Excel sheet or SQL table.

# %% [markdown]
# 4. Explain the use of the groupby() method in Pandas ?

# %% [markdown]
# -> groupby() is used to group data based on column values and apply aggregate functions like mean, sum, etc.

# %% [markdown]
# 5.  Why is Seaborn preferred for statistical visualizations ?

# %% [markdown]
# -> Seaborn provides beautiful default styles, is built on Matplotlib, and supports statistical plots easily.

# %% [markdown]
# 6. What are the differences between NumPy arrays and Python lists ?

# %% [markdown]
# ->
# -           Numpy array :
# Numpy arrays are faster, homogeneous, and used to perform vectorized operation's.
# -           Python List :
# List's are slower, heterogeneous, requires loop.

# %% [markdown]
# 7. What is a heatmap, and when should it be used ?
#
# -> A heatmap is a color-coded matrix used to show relationships or correlations between variables.

# %% [markdown]
# 8. What does the term “vectorized operation” mean in NumPy ?
#
# -> Operations applied to entire arrays at once without using loops.

# %% [markdown]
# 9. How does Matplotlib differ from Plotly ?
#
# ->
# -           Matplotlib :
# Used for staticplots, it is lightweight, and it is simple.
# -           Plotly :
# Show's interactive plot's, it is web based and feature rich.

# %% [markdown]
# 10. What is the significance of hierarchical indexing in Pandas ?
#
# -> It allows multi-level indexing, useful for handling complex datasets.

# %% [markdown]
# 11. What is the role of Seaborn’s pairplot() function ?
#
# -> Displays relationships between multiple numerical variables in one figure.

# %% [markdown]
# 12. What is the purpose of the describe() function in Pandas ?
#
# -> Provides summary statistics like mean, min, max, count, etc. (5-point summary.)

# %% [markdown]
# 13. Why is handling missing data important in Pandas ?
#
# -> Missing data can give wrong results, so it must be handled properly.

# %% [markdown]
# 14. What are the benefits of using Plotly for data visualization ?
#
# -> Interactive graphs
#
# Zoom and hover features
#
# Web-friendly

# %% [markdown]
# 15. How does NumPy handle multidimensional arrays ?
#
# -> Using ndarray, which supports 1D, 2D, and n-D arrays.

# %% [markdown]
# 16. What is the role of Bokeh in data visualization ?
#
# -> Used for interactive and browser-based visualizations.

# %% [markdown]
# 17. Explain the difference between apply() and map() in Pandas.
#
# ->
# -           apply () :
# Works on dataframe as well as on series and it is more flexible.
# -           map () :
# Works on series only and it is simple.

# %% [markdown]
# 18.  What are some advanced features of NumPy ?
#
# -> Broadcasting
#
# Linear algebra
#
# Random number generation
#
# FFT

# %% [markdown]
# 19. How does Pandas simplify time series analysis ?
#
# -> Pandas supports date indexing, resampling, rolling operations.

# %% [markdown]
# 20. What is the role of a pivot table in Pandas ?
#
# -> Summarizes data using aggregation and grouping.

# %% [markdown]
# 21. Why is NumPy’s array slicing faster than Python’s list slicing ?
#
# -> Because NumPy uses contiguous memory allocation.

# %% [markdown]
# 22.  What are some common use cases for Seaborn ?
#
# -> Distribution plots
#
# Correlation analysis
#
# Statistical comparisons

# %% [markdown]
# # Practical :

# %% [markdown]
# 1. How do you create a 2D NumPy array and calculate the sum of each row ?

# %%
import numpy as np

arr = np.array([[1,2,3],[4,5,6]])
print(arr.sum(axis=1))
# Out:
# [ 6 15]

# %% [markdown]
# 2. Write a Pandas script to find the mean of a specific column in a DataFrame ?

# %%
import pandas as pd

df = pd.DataFrame ({
    'Name' : ["Ajay", "Bijay", "Sanjay"], 
    'Marks' : [18, 17, 19]
})

print(df.Marks.mean ())
# Out:
# 18.0

# %% [markdown]
# 3. Create a scatter plot using Matplotlib ?

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [4, 3, 2, 1]

plt.scatter (x, y)
plt.show ()

# %% [markdown]
# 4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap ?

# %%
import seaborn as sns

df = pd.DataFrame({
    'A':[1,2,3],
    'B':[4,5,6]
})

sns.heatmap (df.corr (), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# 5. Generate a bar plot using Plotly ?

# %%
import plotly.express as px

data = {
    "City" : ['A', 'B'],
    "Population" : [100, 200]
}

fig = px.bar (data, x = 'City', y = 'Population')
fig.show ()

# %% [markdown]
# 6. Create a DataFrame and add a new column based on an existing column ?

# %%
df ['double_A'] = df['A']*2
df
# Out:
#    A  B  double_A
# 0  1  4         2
# 1  2  5         4
# 2  3  6         6

# %% [markdown]
# 7. Write a program to perform element-wise multiplication of two NumPy arrays ?

# %%
a = np.array([1,2])
b = np.array([3,4])
print(a * b)
# Out:
# [3 8]

# %% [markdown]
# 8. Create a line plot with multiple lines using Matplotlib ?

# %%
plt.plot([1,2,3],[2,3,4])
plt.plot([1,2,3],[4,5,6])
plt.show()

# %% [markdown]
# 9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold ?

# %%
df[df['double_A'] > 2]
# Out:
#    A  B  double_A
# 1  2  5         4
# 2  3  6         6

# %% [markdown]
# 10. Create a histogram using Seaborn to visualize a distribution ?

# %%
sns.histplot(df['double_A'])
# Out:
# <Axes: xlabel='double_A', ylabel='Count'>

# %% [markdown]
# 11.  Perform matrix multiplication using NumPy ?

# %%
print(np.dot(a, b))
# Out:
# 11

# %% [markdown]
# 12. Use Pandas to load a CSV file and display its first 5 rows ?

# %%
df = pd.read_csv("services.csv")
print(df.head())
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [markdown]
# 13. Create a 3D scatter plot using Plotly.

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length')
fig.show()
